# %% [markdown]
# # Named Entity Linking (NEL) Pipeline
#
# This notebook implements a comprehensive Named Entity Linking system for the GutBrainIE dataset. The pipeline uses a two-stage approach to link predicted entities to their corresponding URIs:
#
# ## **Linking Strategy**
#
# 1. **Exact Matching**: Direct text span matching against manually annotated training data
# 2. **Similarity Matching**: Semantic similarity using PubMedBERT embeddings for entities without exact matches
#
# ## **Pipeline Workflow**
#
# 1. **Extract Training Knowledge**: Build entity-to-URI mappings from gold standard annotations
# 2. **Analyze Coverage**: Evaluate exact match coverage on predicted entities
# 3. **Semantic Similarity**: Use embedding-based similarity for missed entities
# 4. **Final Linking**: Combine exact and similarity matches to assign URIs
#
# ## **Output**
# - Linked entities with URI assignments and confidence sources
# - Statistics on exact matches, similarity matches, and unlinked entities
# - Final predictions in evaluation format
#
# ## **Requirements**
# - GPU recommended for similarity matching (txtai + PubMedBERT)
# - Pre-generated URI definitions from `generate_definitions.ipynb`

# %% [markdown]
# ## Step 1: Extract Entity-to-URI Mappings from Training Data
#
# Build exact matching dictionaries from manually annotated data (dev, train_platinum, train_gold sets). We create mappings from normalized text spans to their corresponding URIs.
#
# **Strategy**: For entities with identical text spans but different URIs, we'll use the first URI found (as noted, better handling could be implemented as future work).

# %% [markdown]
# ### Text Span to URI Mapping (Case-Insensitive)
#
# Extract all entity linkages from training data for exact matching. If a predicted entity's text span (lowercase) matches exactly with training data, we assign the corresponding URI.
#
# **Note**: Some text spans may have multiple URIs in the training data. In such cases, we use the first URI found.

# %%
import json

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GutBrainIE/Train/NEL

# Define paths to training annotation files
# Here we are commenting out the dev set to avoid data leakage when running inference on the dev set
# When evaluating on the test set, uncomment this line to include the dev annotations in the knowledge base
#dev_annotations_path = '../../Annotations/Dev/json_format/dev.json'
train_gold_annotations_path = '../../Annotations/Train/gold_quality/json_format/train_gold.json'
train_silver_annotations_path = '../../Annotations/Train/silver_quality/json_format/train_silver.json'

training_annotation_files = [
    #dev_annotations_path,
    train_gold_annotations_path,
    train_silver_annotations_path
]

# Build mapping from text spans to URIs (case-insensitive)
text_span_to_uris = {}

print("Processing training annotations to build text span -> URI mappings...")

for annotation_file_path in training_annotation_files:
    with open(annotation_file_path, 'r', encoding='utf-8') as input_file:
        annotation_data = json.load(input_file)

    # Process each document's entities
    for document_id, document_content in annotation_data.items():
        for entity in document_content['entities']:
            normalized_text_span = entity['text_span'].lower()
            entity_label = entity['label']
            entity_uri = entity['uri']

            # Initialize set for this text span if not exists
            if normalized_text_span not in text_span_to_uris:
                text_span_to_uris[normalized_text_span] = set()

            # Add URI to the set for this text span
            text_span_to_uris[normalized_text_span].add(entity_uri)

# Analyze text spans with multiple URIs
ambiguous_text_spans_count = 0
for text_span, uri_set in text_span_to_uris.items():
    if len(uri_set) > 1:
        print(f'Ambiguous text span: "{text_span}" has multiple URIs: {uri_set}')
        ambiguous_text_spans_count += 1

print(f'\n=== Text Span Analysis ===')
print(f'Total unique text spans: {len(text_span_to_uris)}')
print(f'Text spans with multiple URIs: {ambiguous_text_spans_count}')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/GutBrainIE/Train/NEL
# Processing training annotations to build text span -> URI mappings...
# Ambiguous text span: "microbial metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "tight junction proteins" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13333', 'http://purl.obolibrary.org/obo/OMIT_0028142'}
# Ambiguous text span: "zo-1" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028142', 'http://purl.obolibrary.org/obo/OMIT_0028159', 'http://purl.obolibrary.org/obo/NCIT_C114824', 'http://purl.obolibrary.org/obo/CHEBI_3254', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous text span: "claudin-5" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0026886', 'http://id.nlm.nih.gov/mesh/D062507'}
# Ambiguous text span: "spinal cord" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C33969', 'http://purl.obolibrary.org/obo/NCIT_C12464'}
# Ambiguous text span: "wt mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C14424', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "il-6" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/OMIT_0016485', 'http://purl.obolibrary.org/obo/NCIT_C24504', 'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous text span: "il-17" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28608', 'http://purl.obolibrary.org/obo/NCIT_C20464'}
# Ambiguous text span: "ifn-γ" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52999', 'http://purl.obolibrary.org/obo/NCIT_C20496'}
# Ambiguous text span: "metabolome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13325', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous text span: "gut microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000016'}
# Ambiguous text span: "individuals" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "metabolomics" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C210457', 'http://purl.obolibrary.org/obo/NCIT_C49019'}
# Ambiguous text span: "depression" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141', 'http://snomed.info/id/1153570009'}
# Ambiguous text span: "metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "gut microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000016'}
# Ambiguous text span: "bacteroidetes" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCIT_C76203'}
# Ambiguous text span: "bacteroidota" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous text span: "oral and gut microbiotas" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "patients" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "oral and gut microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "ad" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "healthy controls" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C94342'}
# Ambiguous text span: "bacteroidetes phyla" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76203', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous text span: "gut" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://purl.obolibrary.org/obo/NCIT_C12736'}
# Ambiguous text span: "verrucomicrobia" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_74201', 'http://purl.obolibrary.org/obo/NCBITaxon_747582'}
# Ambiguous text span: "oral microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000015', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous text span: "fecal microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000001'}
# Ambiguous text span: "vitamins" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C944', 'http://purl.obolibrary.org/obo/CHEBI_27300'}
# Ambiguous text span: "mild and moderate ad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2866', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous text span: "inflammatory state" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3276087', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous text span: "intestinal microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous text span: "microbiota" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "mild cognitive impairment" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C215366', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "older adults" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000328', 'https://uts.nlm.nih.gov/uts/umls/concept/C3826770', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous text span: "increased intestinal permeability" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5578082', 'http://purl.obolibrary.org/obo/NCIT_C53526', 'https://uts.nlm.nih.gov/uts/umls/concept/C1404951'}
# Ambiguous text span: "leaky gut" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5578082', 'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://snomed.info/id/81120009', 'http://purl.obolibrary.org/obo/NCIT_C28193', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578085'}
# Ambiguous text span: "oxidative stress" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C35041', 'http://purl.obolibrary.org/obo/NCIT_C17741'}
# Ambiguous text span: "neurodegenerative changes" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "cognitive decline" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous text span: "microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous text span: "mci" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C215366', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "permutational multivariate analysis of variance" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C53241', 'http://id.nlm.nih.gov/mesh/D015999'}
# Ambiguous text span: "permanova" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C53241', 'http://id.nlm.nih.gov/mesh/D015999'}
# Ambiguous text span: "chao1" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000157', 'http://purl.obolibrary.org/obo/NCIT_C19044'}
# Ambiguous text span: "ad group" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C71468', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "acinetobacter" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_469', 'http://purl.obolibrary.org/obo/NCBITaxon_1591090'}
# Ambiguous text span: "sprague-dawley rats" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D017207'}
# Ambiguous text span: "rats" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017207', 'http://purl.obolibrary.org/obo/NCIT_C160998', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCBITaxon_9989', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous text span: "app" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28537', 'http://purl.obolibrary.org/obo/OMIT_0025607', 'http://purl.obolibrary.org/obo/NCIT_C16285'}
# Ambiguous text span: "bace1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C112893', 'http://purl.obolibrary.org/obo/NCIT_C112895', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous text span: "aβ1-42" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous text span: "gut microbes" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "ci-ad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://purl.obolibrary.org/obo/NCIT_C2866', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "ci-nad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C2866', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "acetate" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_30089', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "cu" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_30052', 'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "human microbiota" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous text span: "experimental autoimmune encephalomyelitis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C34580', 'http://purl.obolibrary.org/obo/NCIT_C3006', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775'}
# Ambiguous text span: "gut dysbiosis" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C162870', 'http://snomed.info/id/1149492007'}
# Ambiguous text span: "eae" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34527', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775', 'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C34580'}
# Ambiguous text span: "axonal damage" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "central nervous system" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005', 'http://purl.obolibrary.org/obo/NCIT_C12438'}
# Ambiguous text span: "periphery" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C25233', 'http://purl.obolibrary.org/obo/NCIT_C13018'}
# Ambiguous text span: "cns autoimmunity" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://www.ebi.ac.uk/efo/EFO_1000870'}
# Ambiguous text span: "scfa" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_26666', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous text span: "ms patients" has multiple URIs: {'http://snomed.info/id/103309006', 'http://purl.obolibrary.org/obo/NCIT_C3243', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "gut microbiota dysbiosis" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous text span: "cognitive deficits" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C37940', 'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "vad" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C85220', 'http://purl.obolibrary.org/obo/NCIT_C34525'}
# Ambiguous text span: "ad pathology" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "liver" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12392', 'http://purl.obolibrary.org/obo/CHEBI_50211'}
# Ambiguous text span: "cortex" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous text span: "aβ42" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous text span: "phosphorylated tau" has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous text span: "β-diversity" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000472', 'http://purl.obolibrary.org/obo/NCIT_C19044'}
# Ambiguous text span: "picrust analysis" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5906995', 'https://uts.nlm.nih.gov/uts/umls/concept/C4761062'}
# Ambiguous text span: "app/ps1 transgenic mice" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "ms" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "pwms" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://snomed.info/id/103309006', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "hc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_100756', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C94342'}
# Ambiguous text span: "dmt" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_16765', 'http://snomed.info/id/1340273002', 'http://purl.obolibrary.org/obo/NCIT_C170629'}
# Ambiguous text span: "interferon beta1a" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52999', 'http://purl.obolibrary.org/obo/NCIT_C20495'}
# Ambiguous text span: "teriflunomide" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C459', 'http://purl.obolibrary.org/obo/NCIT_C76662'}
# Ambiguous text span: "beta diversity analyses" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000472', 'http://purl.obolibrary.org/obo/NCIT_C25391'}
# Ambiguous text span: "ms group" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "dmts" has multiple URIs: {'http://snomed.info/id/1340273002', 'http://purl.obolibrary.org/obo/NCIT_C170629'}
# Ambiguous text span: "vascular dementia" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34525', 'http://purl.obolibrary.org/obo/NCIT_C4786'}
# Ambiguous text span: "interleukin-1 beta" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous text span: "il-1β" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous text span: "cs" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_346985', 'http://purl.obolibrary.org/obo/CHEBI_16261'}
# Ambiguous text span: "ad rats" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14182', 'http://purl.obolibrary.org/obo/NCIT_C160998', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "memory impairment" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C78444'}
# Ambiguous text span: "bacteroidales" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_171549'}
# Ambiguous text span: "aβ" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C078592', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous text span: "neurofibrillary tangles" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016874', 'http://purl.obolibrary.org/obo/NCIT_C75652'}
# Ambiguous text span: "neuropsychiatric disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/MONDO_0859292', 'https://uts.nlm.nih.gov/uts/umls/concept/C6013326', 'http://purl.obolibrary.org/obo/NCIT_C2893'}
# Ambiguous text span: "intestinal mucosal barrier" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49241', 'http://snomed.info/id/360972004'}
# Ambiguous text span: "cognitive deficit" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous text span: "gut microbiomes" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "il-8" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/OMIT_0016751', 'http://purl.obolibrary.org/obo/NCIT_C24507'}
# Ambiguous text span: "mcp-1" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20907', 'http://purl.obolibrary.org/obo/NCIT_C20482'}
# Ambiguous text span: "parabacteroides distasonis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_375288', 'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCIT_C76203'}
# Ambiguous text span: "ad mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "ala" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_27432', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "neurodegeneration" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "eicosanoids" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C463', 'http://purl.obolibrary.org/obo/NCIT_C61426'}
# Ambiguous text span: "eicosapentaenoic acid" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_193189', 'http://purl.obolibrary.org/obo/NCIT_C67080'}
# Ambiguous text span: "tg" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_16670', 'http://purl.obolibrary.org/obo/CHEBI_17855', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C2304'}
# Ambiguous text span: "wt" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C42708', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "app/ps1" has multiple URIs: {'http://www.informatics.jax.org/allele/MGI:3524957', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "tg mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous text span: "aea" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_167098', 'http://purl.obolibrary.org/obo/HP_0034070'}
# Ambiguous text span: "mhcii" has multiple URIs: {'http://purl.obolibrary.org/obo/GO_0042613', 'http://purl.obolibrary.org/obo/NCIT_C16812'}
# Ambiguous text span: "apoe4" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C105362', 'http://purl.obolibrary.org/obo/NCIT_C105364'}
# Ambiguous text span: "gm" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "neurodegenerative diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C89338'}
# Ambiguous text span: "app/ps1 mice" has multiple URIs: {'http://www.informatics.jax.org/allele/MGI:3524957', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous text span: "intestinal bacteria" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCBITaxon_188930', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous text span: "neuronal damage" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/TXPO_0000225', 'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous text span: "16s rrna sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "metabolomic analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49019', 'http://www.ebi.ac.uk/efo/EFO_0000752', 'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110'}
# Ambiguous text span: "bv-2 cells" has multiple URIs: {'http://purl.obolibrary.org/obo/BTO_0003350', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous text span: "fecal microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous text span: "people" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C18241', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "digestive tract" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://snomed.info/id/1255345008'}
# Ambiguous text span: "mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14424'}
# Ambiguous text span: "eae mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "microbiome alterations" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C28344'}
# Ambiguous text span: "gmr-aβ42" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_7227', 'http://purl.obolibrary.org/obo/CHEBI_64647'}
# Ambiguous text span: "lactobacillus sakei probio65" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93144', 'http://purl.obolibrary.org/obo/NCIT_C76352'}
# Ambiguous text span: "l. paracasei 0291" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93144', 'http://purl.obolibrary.org/obo/NCIT_C123494'}
# Ambiguous text span: "stenotrophomonas" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1236', 'http://purl.obolibrary.org/obo/NCBITaxon_40323'}
# Ambiguous text span: "late-onset alzheimer's disease" has multiple URIs: {'http://www.ebi.ac.uk/efo/EFO_1001870', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "psd-95" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C033652', 'http://purl.obolibrary.org/obo/NCIT_C29570', 'http://purl.obolibrary.org/obo/CHEBI_198287'}
# Ambiguous text span: "tnf-α" has multiple URIs: {'http://purl.obolibrary.org/obo/PR_P06804', 'http://purl.obolibrary.org/obo/NCIT_C20535', 'http://purl.obolibrary.org/obo/NCIT_C18368'}
# Ambiguous text span: "il-10" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20512', 'http://purl.obolibrary.org/obo/NCIT_C28600'}
# Ambiguous text span: "female mice" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "ketogenic diet" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000072001', 'http://snomed.info/id/765060000'}
# Ambiguous text span: "kd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://snomed.info/id/765060000'}
# Ambiguous text span: "lactobacillus reuteri" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76352', 'http://purl.obolibrary.org/obo/NCBITaxon_1598'}
# Ambiguous text span: "msc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C43423'}
# Ambiguous text span: "carnitine" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C15222', 'http://purl.obolibrary.org/obo/NCIT_C82599'}
# Ambiguous text span: "humans" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_9605', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "csf" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12438', 'http://purl.obolibrary.org/obo/NCIT_C12692', 'http://purl.obolibrary.org/obo/NCIT_C387'}
# Ambiguous text span: "ca" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/OMIT_0003593'}
# Ambiguous text span: "fa" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_213421', 'http://purl.obolibrary.org/obo/NCIT_C184730'}
# Ambiguous text span: "16 s rdna sequencing" has multiple URIs: {'http://id.nlm.nih.gov/mesh/68017421', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "firmicutes/bacteroidetes" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189550', 'http://id.nlm.nih.gov/mesh/D001439'}
# Ambiguous text span: "female rats" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C160998'}
# Ambiguous text span: "females" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C46110'}
# Ambiguous text span: "males" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005', 'http://purl.obolibrary.org/obo/NCIT_C14366'}
# Ambiguous text span: "hs" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://snomed.info/id/442831000124108', 'http://id.nlm.nih.gov/mesh/D018882'}
# Ambiguous text span: "gut microbiome dysbiosis" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous text span: "t2d subjects" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "actinobacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2013654', 'http://id.nlm.nih.gov/mesh/D039903'}
# Ambiguous text span: "fecal microbiota transplantation" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000001', 'http://purl.obolibrary.org/obo/NCIT_C118643'}
# Ambiguous text span: "fmt" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000001', 'http://purl.obolibrary.org/obo/NCIT_C118643'}
# Ambiguous text span: "cognitive function" has multiple URIs: {'http://snomed.info/id/373930000', 'http://purl.obolibrary.org/obo/NCIT_C16446'}
# Ambiguous text span: "16s ribosomal rna sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "y-maze" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000073219', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000014'}
# Ambiguous text span: "pro-inflammatory cytokines" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/NCIT_C50928'}
# Ambiguous text span: "short-chain fatty acid" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_26666', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000182'}
# Ambiguous text span: "erysipelatoclostridium" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_3025755', 'http://id.nlm.nih.gov/mesh/D004888'}
# Ambiguous text span: "gut barrier disruption" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C25486'}
# Ambiguous text span: "metastatic colorectal cancer" has multiple URIs: {'http://www.ebi.ac.uk/efo/EFO_1001480', 'http://purl.obolibrary.org/obo/NCIT_C2955'}
# Ambiguous text span: "persons" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "neurodegenerative disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://id.nlm.nih.gov/mesh/D019636'}
# Ambiguous text span: "tau protein" has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://purl.obolibrary.org/obo/NCIT_C26532'}
# Ambiguous text span: "nrf2" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/NCIT_C54255'}
# Ambiguous text span: "autophagy" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C71427', 'http://id.nlm.nih.gov/mesh/D000080549'}
# Ambiguous text span: "ts" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C35078', 'http://purl.obolibrary.org/obo/CHEBI_189705'}
# Ambiguous text span: "p62" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C491079', 'http://purl.obolibrary.org/obo/OMIT_0037033'}
# Ambiguous text span: "ndp52" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C000597434', 'http://purl.obolibrary.org/obo/NCIT_C217297'}
# Ambiguous text span: "nf-κb" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCIT_C17380'}
# Ambiguous text span: "synaptic loss" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'https://uts.nlm.nih.gov/uts/umls/concept/C5394342'}
# Ambiguous text span: "gut microbiota disorder" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous text span: "high-salt diet" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C15222', 'http://purl.obolibrary.org/obo/NCIT_C15447'}
# Ambiguous text span: "hsd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C15222', 'http://purl.obolibrary.org/obo/NCIT_C15447'}
# Ambiguous text span: "anxiety-like behavior" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://www.ebi.ac.uk/efo/EFO_1001877'}
# Ambiguous text span: "shuttle box" has multiple URIs: {'http://purl.obolibrary.org/obo/MMO_0000725', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous text span: "anxiety-related behavior" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://www.ebi.ac.uk/efo/EFO_1001877'}
# Ambiguous text span: "gut microbiota-derived metabolite" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000150', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "dietary phosphatidylcholine" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C15222', 'http://purl.obolibrary.org/obo/CHEBI_64482'}
# Ambiguous text span: "pa" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61911', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous text span: "rct" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016449', 'http://purl.obolibrary.org/obo/NCIT_C46079'}
# Ambiguous text span: "adults" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000328', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "probiotic group" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "synbiotic group" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "placebo group" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "prebiotic diet" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000072001', 'http://purl.obolibrary.org/obo/NCIT_C15222'}
# Ambiguous text span: "placebo" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C753', 'http://purl.obolibrary.org/obo/NCIT_C203925', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'https://uts.nlm.nih.gov/uts/umls/concept/C1249327'}
# Ambiguous text span: "brain disorders" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous text span: "spf mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_9989', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "pd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous text span: "healthy spouses" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C62649', 'http://purl.obolibrary.org/obo/OMIT_0018651'}
# Ambiguous text span: "sp" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C62649', 'http://purl.obolibrary.org/obo/NCIT_C847'}
# Ambiguous text span: "extracellular vesicles" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000049', 'http://purl.obolibrary.org/obo/NCIT_C153165', 'http://purl.obolibrary.org/obo/OMIT_0001136'}
# Ambiguous text span: "bactev" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C153165', 'http://purl.obolibrary.org/obo/OMIT_0001136'}
# Ambiguous text span: "tissues" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C38625', 'http://purl.obolibrary.org/obo/NCIT_C12801'}
# Ambiguous text span: "16s rrna gene sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "behavioural deficits" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://snomed.info/id/284501001'}
# Ambiguous text span: "op" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3298', 'http://purl.obolibrary.org/obo/CHEBI_39093'}
# Ambiguous text span: "fecal samples" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C25662', 'http://purl.obolibrary.org/obo/NCIT_C200884'}
# Ambiguous text span: "gut microbiome composition" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous text span: "gut microbiota alterations" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C28344'}
# Ambiguous text span: "neurodegenerative disorder" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C195952'}
# Ambiguous text span: "intraperitoneal injection" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25409', 'http://purl.obolibrary.org/obo/NCIT_C28160'}
# Ambiguous text span: "antibiotics treatment" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49236', 'http://purl.obolibrary.org/obo/NCIT_C15620'}
# Ambiguous text span: "pd mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "propionate" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61911', 'http://purl.obolibrary.org/obo/NCIT_C2337', 'http://purl.obolibrary.org/obo/OMIT_0012372'}
# Ambiguous text span: "ffar3" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C000610069', 'http://purl.obolibrary.org/obo/OMIT_0032349'}
# Ambiguous text span: "ginsenoside rk3" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C472075', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous text span: "depressive-like behavior" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous text span: "nervous system" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12755', 'http://purl.obolibrary.org/obo/NCIT_C12438'}
# Ambiguous text span: "rk3" has multiple URIs: {'http://id.nlm.nih.gov/mesh/C472075', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous text span: "depression-like behavior" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous text span: "brain tissue" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://snomed.info/id/256865009'}
# Ambiguous text span: "butyricimonas" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://id.nlm.nih.gov/mesh/D045856', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous text span: "ace" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3367', 'http://purl.obolibrary.org/obo/NCIT_C19247', 'http://purl.obolibrary.org/obo/NCIT_C19044'}
# Ambiguous text span: "subjects" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C18241', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C70668', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "autism spectrum disorder" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C97161', 'http://purl.obolibrary.org/obo/NCIT_C89330', 'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C26835'}
# Ambiguous text span: "α-synuclein" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C21217', 'http://purl.obolibrary.org/obo/NCIT_C90119'}
# Ambiguous text span: "children" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D002648', 'http://purl.obolibrary.org/obo/NCIT_C42708'}
# Ambiguous text span: "asd" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C97161'}
# Ambiguous text span: "parkinson's and alzheimer's diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "tgr5" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26103', 'http://purl.obolibrary.org/obo/NCIT_C2304'}
# Ambiguous text span: "ischemic stroke" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95802', 'http://purl.obolibrary.org/obo/NCIT_C3390'}
# Ambiguous text span: "social isolation" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C21100', 'https://uts.nlm.nih.gov/uts/umls/concept/C0855237'}
# Ambiguous text span: "intestinal barrier" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49240', 'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://snomed.info/id/360972004', 'http://purl.obolibrary.org/obo/NCIT_C49478'}
# Ambiguous text span: "male balb/c mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C37357', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "bifidobacterium longum" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1678', 'http://purl.obolibrary.org/obo/NCIT_C86199'}
# Ambiguous text span: "chronic unpredictable mild stress" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1510527', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous text span: "cums" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1510527', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous text span: "lc3" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C104677', 'http://purl.obolibrary.org/obo/CHEBI_36080'}
# Ambiguous text span: "mptp" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_233275', 'http://purl.obolibrary.org/obo/CHEBI_17963'}
# Ambiguous text span: "bile salt hydrolase" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16701', 'http://purl.obolibrary.org/obo/CHEBI_22868'}
# Ambiguous text span: "bsh" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16701', 'http://purl.obolibrary.org/obo/CHEBI_22868'}
# Ambiguous text span: "glp-1r" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_80270', 'http://purl.obolibrary.org/obo/OMIT_0001212', 'http://purl.obolibrary.org/obo/NCIT_C18106'}
# Ambiguous text span: "sod" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D013482', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous text span: "hcs" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C94342', 'http://purl.obolibrary.org/obo/NCBITaxon_9605'}
# Ambiguous text span: "alpha diversity indices" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000471', 'http://purl.obolibrary.org/obo/PCO_0000062'}
# Ambiguous text span: "peripheral tissues" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25233', 'http://purl.obolibrary.org/obo/NCIT_C38625'}
# Ambiguous text span: "alzheimer's and parkinson's disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous text span: "major depression" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/NCIT_C35094'}
# Ambiguous text span: "rf" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000093743', 'http://purl.obolibrary.org/obo/NCIT_C61926'}
# Ambiguous text span: "frontal cortex" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C177766', 'http://purl.obolibrary.org/obo/NCIT_C154779'}
# Ambiguous text span: "cerebellum" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://purl.obolibrary.org/obo/NCIT_C12445'}
# Ambiguous text span: "heart" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13023', 'http://purl.obolibrary.org/obo/NCIT_C12727'}
# Ambiguous text span: "neurological disorders" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://id.nlm.nih.gov/mesh/D009461', 'http://purl.obolibrary.org/obo/NCIT_C26835'}
# Ambiguous text span: "16s rrna gene amplicon sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "serum metabolome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13325', 'http://purl.obolibrary.org/obo/CHEBI_85234', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous text span: "bacteroides vulgatus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86182', 'http://id.nlm.nih.gov/mesh/D001439'}
# Ambiguous text span: "serum metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_85234', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "glutamate" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C1115', 'http://purl.obolibrary.org/obo/NCIT_C687'}
# Ambiguous text span: "altered gut microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028544'}
# Ambiguous text span: "butyricicoccus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_580596', 'http://id.nlm.nih.gov/mesh/D045856', 'http://purl.obolibrary.org/obo/NCBITaxon_186801'}
# Ambiguous text span: "gut mycobiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/OHMI_0000006'}
# Ambiguous text span: "gut bacterial dysbiosis" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous text span: "mycobiome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/OHMI_0000006'}
# Ambiguous text span: "intestinal microbiome" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous text span: "relapsing-remitting multiple sclerosis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C165675', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "rrms" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C165675', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "ms disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3243', 'http://purl.obolibrary.org/obo/NCIT_C34527'}
# Ambiguous text span: "is" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3390', 'http://purl.obolibrary.org/obo/NCIT_C95802', 'https://uts.nlm.nih.gov/uts/umls/concept/C1840264'}
# Ambiguous text span: "neuronal cells" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12623', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous text span: "interleukin-6" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C50940', 'http://purl.obolibrary.org/obo/OMIT_0016485'}
# Ambiguous text span: "western blot" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_37704', 'http://id.nlm.nih.gov/mesh/D015153'}
# Ambiguous text span: "proteins" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/CHEBI_82131'}
# Ambiguous text span: "tnf" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20500', 'http://purl.obolibrary.org/obo/NCIT_C20535', 'http://purl.obolibrary.org/obo/NCIT_C18368'}
# ...
# Ambiguous text span: "flies" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_381473', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000085'}
# Ambiguous text span: "lactiplantibacillus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33958', 'http://purl.obolibrary.org/obo/NCBITaxon_1590'}
# Ambiguous text span: "nitrogen" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61863', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous text span: "age-related pathologies" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'https://uts.nlm.nih.gov/uts/umls/concept/C0851830'}
# Ambiguous text span: "fatty liver disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C84444', 'http://purl.obolibrary.org/obo/MONDO_0004790'}
# Ambiguous text span: "pbc" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C196862', 'http://purl.obolibrary.org/obo/NCIT_C27167'}
# Ambiguous text span: "fecal metagenomics" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5906995', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841'}
# Ambiguous text span: "lipid metabolism" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25739', 'http://purl.obolibrary.org/obo/NCIT_C40645'}
# Ambiguous text span: "16 s rrna sequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous text span: "control participants" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C29867', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous text span: "ruthenibacterium lactatiformans" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1550024', 'http://purl.obolibrary.org/obo/NCBITaxon_186801'}
# Ambiguous text span: "neutrophils" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/OMIT_0010527'}
# Ambiguous text span: "nk46" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1678', 'http://purl.obolibrary.org/obo/NCIT_C86199'}
# Ambiguous text span: "c. butyricum" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D003013', 'http://purl.obolibrary.org/obo/NCIT_C86273'}
# Ambiguous text span: "histidine" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C29597'}
# Ambiguous text span: "stool" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C13234'}
# Ambiguous text span: "ad-like pathology" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous text span: "behavioral testing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_457483', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous text span: "bfubb" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCBITaxon_33078'}
# Ambiguous text span: "senescence-accelerated mouse prone 8 (samp8) mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "h&e staining" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C23011', 'http://purl.obolibrary.org/obo/NCIT_C23010'}
# Ambiguous text span: "aged samp8 mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "colonic bacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'https://uts.nlm.nih.gov/uts/umls/concept/C3510360'}
# Ambiguous text span: "nucleic acids" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous text span: "periodontal disease" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C63743'}
# Ambiguous text span: "blood microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000124'}
# Ambiguous text span: "gut microbiome analysis" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous text span: "candidatus arthromitus" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCBITaxon_33078'}
# Ambiguous text span: "galt" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000198', 'http://purl.obolibrary.org/obo/NCIT_C13049'}
# Ambiguous text span: "aβ<sub>42</sub>" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64647', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous text span: "enteric microbiome" has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196'}
# Ambiguous text span: "leptotrichia" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCIT_C86014'}
# Ambiguous text span: "fecal bacteria" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous text span: "gut microbiome community" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000200'}
# Ambiguous text span: "ms twins" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous text span: "cells" has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous text span: "americans" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C16310', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "teer" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017097', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000062'}
# Ambiguous text span: "adonis test" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C53241', 'http://id.nlm.nih.gov/mesh/D015999'}
# Ambiguous text span: "da" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_18243', 'http://purl.obolibrary.org/obo/CHEBI_42111'}
# Ambiguous text span: "dopaminergic neuronal damage" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/HP_0002529'}
# Ambiguous text span: "chronic inflammatory diseases" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C174450', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous text span: "evs" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000049', 'http://purl.obolibrary.org/obo/NCIT_C153165'}
# Ambiguous text span: "anti-gal" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C121503', 'http://purl.obolibrary.org/obo/NCIT_C16295'}
# Ambiguous text span: "hesperidin" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C70554', 'http://purl.obolibrary.org/obo/NCIT_C68460'}
# Ambiguous text span: "nobiletin" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C70554', 'http://purl.obolibrary.org/obo/CHEBI_7602'}
# Ambiguous text span: "experimental autoimmune encephalitis" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26760', 'http://purl.obolibrary.org/obo/NCIT_C3006'}
# Ambiguous text span: "nmd" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/CHEBI_31882', 'http://purl.obolibrary.org/obo/NCIT_C692'}
# Ambiguous text span: "buried food test" has multiple URIs: {'http://snomed.info/id/252249003', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous text span: "pole descent test" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C47891', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous text span: "pyriform cortex" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D066195', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous text span: "pms" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "indole-3-lactic acid" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_42111', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous text span: "metabolite-sensing gpcrs" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39001', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous text span: "gpr43" has multiple URIs: {'http://purl.obolibrary.org/obo/PR_000001583', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous text span: "gpr41" has multiple URIs: {'http://purl.obolibrary.org/obo/PR_000001584', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous text span: "p-cresol" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous text span: "oral administration" has multiple URIs: {'http://purl.obolibrary.org/obo/OBI_0000952', 'http://snomed.info/id/394899003'}
# Ambiguous text span: "intestinal cells" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49240', 'http://snomed.info/id/250436000'}
# Ambiguous text span: "campylobacterota" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_29547', 'http://id.nlm.nih.gov/mesh/D020560'}
# Ambiguous text span: "stool sample" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C200884'}
# Ambiguous text span: "retinoic acid" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C68301', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous text span: "vitamin a" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C944', 'http://purl.obolibrary.org/obo/CHEBI_12777'}
# Ambiguous text span: "pyrosequencing" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C99481', 'http://purl.obolibrary.org/obo/NCIT_C101293'}
# Ambiguous text span: "genetically predisposed individuals" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous text span: "commensals" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous text span: "fecal and oral microbiomes" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000015'}
# Ambiguous text span: "muc2" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0010119', 'http://purl.obolibrary.org/obo/NCIT_C115187'}
# Ambiguous text span: "total cholesterol" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61032', 'http://purl.obolibrary.org/obo/CHEBI_16113'}
# Ambiguous text span: "psmd" has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0024149', 'http://purl.obolibrary.org/obo/NCIT_C16342'}
# Ambiguous text span: "depression-like behaviours" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous text span: "tryptophan metabolism" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25739', 'http://purl.obolibrary.org/obo/NCIT_C38875', 'http://purl.obolibrary.org/obo/CHEBI_27897', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous text span: "metabolomic profiles" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C210457', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110'}
# Ambiguous text span: "y maze test" has multiple URIs: {'http://purl.obolibrary.org/obo/MMO_0000609', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000014'}
# Ambiguous text span: "neuronal senescence" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17467', 'http://id.nlm.nih.gov/mesh/D016922'}
# Ambiguous text span: "central nervous system autoimmunity" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2934', 'http://purl.obolibrary.org/obo/OMIT_0016272'}
# Ambiguous text span: "small intestine lymphoid tissues" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13049', 'http://purl.obolibrary.org/obo/NCIT_C12386'}
# Ambiguous text span: "zinc chloride" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C29865', 'http://purl.obolibrary.org/obo/NCIT_C948'}
# Ambiguous text span: "enterobacteriales" has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_91347', 'http://purl.obolibrary.org/obo/NCIT_C76310'}
# Ambiguous text span: "3 × tg-ad mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous text span: "hd mice" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous text span: "pparα" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D047495', 'http://purl.obolibrary.org/obo/PR_000013056'}
# Ambiguous text span: "microbiota metabolites" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous text span: "li01" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95186', 'http://purl.obolibrary.org/obo/NCBITaxon_2767887'}
# Ambiguous text span: "hplc" has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000048', 'http://purl.obolibrary.org/obo/NCIT_C16434'}
# Ambiguous text span: "kyna" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_28683', 'http://purl.obolibrary.org/obo/CHEBI_18344'}
# Ambiguous text span: "dnp" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26748', 'http://purl.obolibrary.org/obo/CHEBI_53289'}
# Ambiguous text span: "microglia activation" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C64382', 'http://purl.obolibrary.org/obo/GO_0001774'}
# Ambiguous text span: "cns-directed autoimmunity" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2934', 'http://purl.obolibrary.org/obo/OMIT_0016272'}
# Ambiguous text span: "p21" has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCIT_C17783'}
# Ambiguous text span: "svd" has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0262405', 'http://id.nlm.nih.gov/mesh/D059345'}
# Ambiguous text span: "human gut commensal" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089'}
# Ambiguous text span: "weighted gene co-expression network analysis" has multiple URIs: {'http://edamontology.org/operation_3766', 'http://purl.obolibrary.org/obo/NCIT_C25391'}
# Ambiguous text span: "rps3a" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/OMIT_0034986'}
# Ambiguous text span: "rpl5" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/NCIT_C107652'}
# Ambiguous text span: "pediatric multiple sclerosis" has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous text span: "viral-induced neurologic damage" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/NCIT_C61555'}
# Ambiguous text span: "axl" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18359', 'http://purl.obolibrary.org/obo/NCIT_C18106'}
# Ambiguous text span: "thc" has multiple URIs: {'http://snomed.info/id/72024007', 'http://purl.obolibrary.org/obo/NCIT_C459'}
# Ambiguous text span: "pip" has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192634', 'http://purl.obolibrary.org/obo/CHEBI_22315'}
# Ambiguous text span: "e. faecalis" has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016983', 'http://purl.obolibrary.org/obo/NCIT_C86368'}
#
# === Text Span Analysis ===
# Total unique text spans: 14387
# Text spans with multiple URIs: 1033

# %% [markdown]
# ### Text Span + Label to URI Mapping
#
# Create a more precise mapping that considers both text span AND entity label. This provides additional specificity for disambiguation when the same text can represent different entity types.

# %%
# Build mapping from (text_span, label) tuples to URIs
text_span_label_to_uris = {}

print("Building (text_span, label) -> URI mappings...")

for annotation_file_path in training_annotation_files:
    with open(annotation_file_path, 'r', encoding='utf-8') as input_file:
        annotation_data = json.load(input_file)

    # Process each document's entities
    for document_id, document_content in annotation_data.items():
        for entity in document_content['entities']:
            normalized_text_span = entity['text_span'].lower()
            entity_label = entity['label']
            entity_uri = entity['uri']

            # Create composite key from text span and label
            composite_key = (normalized_text_span, entity_label)

            # Initialize set for this composite key if not exists
            if composite_key not in text_span_label_to_uris:
                text_span_label_to_uris[composite_key] = set()

            # Add URI to the set for this composite key
            text_span_label_to_uris[composite_key].add(entity_uri)

# Analyze composite keys with multiple URIs
ambiguous_composite_keys_count = 0
for (text_span, label), uri_set in text_span_label_to_uris.items():
    if len(uri_set) > 1:
        print(f'Ambiguous: "{text_span}" (label: {label}) has multiple URIs: {uri_set}')
        ambiguous_composite_keys_count += 1

print(f'\n=== Text Span + Label Analysis ===')
print(f'Total unique (text_span, label) pairs: {len(text_span_label_to_uris)}')
print(f'Pairs with multiple URIs: {ambiguous_composite_keys_count}')
# Out:
# Building (text_span, label) -> URI mappings...
# Ambiguous: "microbial metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "tight junction proteins" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13333', 'http://purl.obolibrary.org/obo/OMIT_0028142'}
# Ambiguous: "spinal cord" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C33969', 'http://purl.obolibrary.org/obo/NCIT_C12464'}
# Ambiguous: "wt mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C14424', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "il-6" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/OMIT_0016485', 'http://purl.obolibrary.org/obo/NCIT_C24504', 'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous: "il-17" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28608', 'http://purl.obolibrary.org/obo/NCIT_C20464'}
# Ambiguous: "ifn-γ" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52999', 'http://purl.obolibrary.org/obo/NCIT_C20496'}
# Ambiguous: "metabolome" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13325', 'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous: "gut microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000016'}
# Ambiguous: "individuals" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "depression" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141', 'http://snomed.info/id/1153570009'}
# Ambiguous: "metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "gut microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000016'}
# Ambiguous: "bacteroidetes" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCIT_C76203'}
# Ambiguous: "bacteroidota" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous: "oral and gut microbiotas" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "patients" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "oral and gut microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "healthy controls" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C94342'}
# Ambiguous: "bacteroidetes phyla" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76203', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous: "gut" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://purl.obolibrary.org/obo/NCIT_C12736'}
# Ambiguous: "verrucomicrobia" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_74201', 'http://purl.obolibrary.org/obo/NCBITaxon_747582'}
# Ambiguous: "oral microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000015', 'http://purl.obolibrary.org/obo/OMIT_0028418'}
# Ambiguous: "fecal microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "mild and moderate ad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2866', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous: "inflammatory state" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C3276087', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous: "intestinal microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "microbiota" (label: microbiome) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/OHMI_0000002', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "mild cognitive impairment" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C215366', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "older adults" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000328', 'https://uts.nlm.nih.gov/uts/umls/concept/C3826770', 'http://purl.obolibrary.org/obo/NCIT_C16268'}
# Ambiguous: "increased intestinal permeability" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5578082', 'http://purl.obolibrary.org/obo/NCIT_C53526', 'https://uts.nlm.nih.gov/uts/umls/concept/C1404951'}
# Ambiguous: "leaky gut" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5578082', 'http://snomed.info/id/81120009', 'https://uts.nlm.nih.gov/uts/umls/concept/C5578085', 'http://purl.obolibrary.org/obo/NCIT_C28193'}
# Ambiguous: "oxidative stress" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C35041', 'http://purl.obolibrary.org/obo/NCIT_C17741'}
# Ambiguous: "neurodegenerative changes" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "cognitive decline" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous: "microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous: "mci" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C215366', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "permutational multivariate analysis of variance" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C53241', 'http://id.nlm.nih.gov/mesh/D015999'}
# Ambiguous: "permanova" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C53241', 'http://id.nlm.nih.gov/mesh/D015999'}
# Ambiguous: "chao1" (label: statistical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000157', 'http://purl.obolibrary.org/obo/NCIT_C19044'}
# Ambiguous: "ad group" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C71468'}
# Ambiguous: "acinetobacter" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_469', 'http://purl.obolibrary.org/obo/NCBITaxon_1591090'}
# Ambiguous: "sprague-dawley rats" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D017207'}
# Ambiguous: "rats" (label: animal) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017207', 'http://purl.obolibrary.org/obo/NCIT_C160998', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCBITaxon_9989', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous: "app" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28537', 'http://purl.obolibrary.org/obo/NCIT_C16285'}
# Ambiguous: "aβ1-42" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous: "gut microbes" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "ci-ad" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "ci-nad" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "acetate" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_30089', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "cu" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "human microbiota" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous: "experimental autoimmune encephalomyelitis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C34580', 'http://purl.obolibrary.org/obo/NCIT_C3006', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775'}
# Ambiguous: "gut dysbiosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C162870', 'http://snomed.info/id/1149492007'}
# Ambiguous: "eae" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34527', 'https://uts.nlm.nih.gov/uts/umls/concept/C5681775', 'http://purl.obolibrary.org/obo/NCIT_C3006', 'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/NCIT_C34580'}
# Ambiguous: "axonal damage" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "periphery" (label: anatomical location) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C25233', 'http://purl.obolibrary.org/obo/NCIT_C13018'}
# Ambiguous: "cns autoimmunity" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2889', 'http://purl.obolibrary.org/obo/OMIT_0016272', 'http://www.ebi.ac.uk/efo/EFO_1000870'}
# Ambiguous: "ms patients" (label: human) has multiple URIs: {'http://snomed.info/id/103309006', 'http://purl.obolibrary.org/obo/NCIT_C3243', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "gut microbiota dysbiosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous: "cognitive deficits" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C37940', 'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C92196', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "vad" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C85220', 'http://purl.obolibrary.org/obo/NCIT_C34525'}
# Ambiguous: "ad pathology" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "cortex" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous: "aβ42" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C075222', 'http://purl.obolibrary.org/obo/CHEBI_64647', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous: "bace1" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C112895', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous: "phosphorylated tau" (label: chemical) has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://snomed.info/id/412631008'}
# Ambiguous: "β-diversity" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000472', 'http://purl.obolibrary.org/obo/NCIT_C19044'}
# Ambiguous: "picrust analysis" (label: biomedical technique) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5906995', 'https://uts.nlm.nih.gov/uts/umls/concept/C4761062'}
# Ambiguous: "app/ps1 transgenic mice" (label: animal) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "pwms" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14225', 'http://snomed.info/id/103309006', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "hc" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C94342'}
# Ambiguous: "dmt" (label: biomedical technique) has multiple URIs: {'http://snomed.info/id/1340273002', 'http://purl.obolibrary.org/obo/NCIT_C170629'}
# Ambiguous: "beta diversity analyses" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000472', 'http://purl.obolibrary.org/obo/NCIT_C25391'}
# Ambiguous: "ms group" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "dmts" (label: biomedical technique) has multiple URIs: {'http://snomed.info/id/1340273002', 'http://purl.obolibrary.org/obo/NCIT_C170629'}
# Ambiguous: "vascular dementia" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34525', 'http://purl.obolibrary.org/obo/NCIT_C4786'}
# Ambiguous: "interleukin-1 beta" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous: "il-1β" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/NCIT_C50928', 'http://purl.obolibrary.org/obo/NCIT_C20522'}
# Ambiguous: "ad rats" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14182', 'http://purl.obolibrary.org/obo/NCIT_C160998', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "memory impairment" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://purl.obolibrary.org/obo/NCIT_C78444'}
# Ambiguous: "bacteroidales" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCBITaxon_171549'}
# Ambiguous: "aβ" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C078592', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous: "neurofibrillary tangles" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016874', 'http://purl.obolibrary.org/obo/NCIT_C75652'}
# Ambiguous: "neuropsychiatric disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/MONDO_0859292', 'https://uts.nlm.nih.gov/uts/umls/concept/C6013326', 'http://purl.obolibrary.org/obo/NCIT_C2893'}
# Ambiguous: "intestinal mucosal barrier" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49241', 'http://snomed.info/id/360972004'}
# Ambiguous: "cognitive deficit" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C46083', 'http://purl.obolibrary.org/obo/NCIT_C116921'}
# Ambiguous: "gut microbiomes" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "il-8" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/OMIT_0016751', 'http://purl.obolibrary.org/obo/NCIT_C24507'}
# Ambiguous: "mcp-1" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20907', 'http://purl.obolibrary.org/obo/NCIT_C20482'}
# Ambiguous: "parabacteroides distasonis" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_375288', 'http://id.nlm.nih.gov/mesh/D001439', 'http://purl.obolibrary.org/obo/NCIT_C76203'}
# Ambiguous: "ad mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://id.nlm.nih.gov/mesh/D055647', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "neurodegeneration" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "eicosanoids" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C463', 'http://purl.obolibrary.org/obo/NCIT_C61426'}
# Ambiguous: "eicosapentaenoic acid" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_193189', 'http://purl.obolibrary.org/obo/NCIT_C67080'}
# Ambiguous: "wt" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C42708', 'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "app/ps1" (label: animal) has multiple URIs: {'http://www.informatics.jax.org/allele/MGI:3524957', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "tg mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous: "aea" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_167098', 'http://purl.obolibrary.org/obo/HP_0034070'}
# Ambiguous: "gm" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://purl.obolibrary.org/obo/NCIT_C14329'}
# Ambiguous: "neurodegenerative diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://id.nlm.nih.gov/mesh/D019636', 'http://purl.obolibrary.org/obo/NCIT_C89338'}
# Ambiguous: "app/ps1 mice" (label: animal) has multiple URIs: {'http://www.informatics.jax.org/allele/MGI:3524957', 'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous: "intestinal bacteria" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCBITaxon_188930', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous: "neuronal damage" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/TXPO_0000225', 'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C1395088'}
# Ambiguous: "16s rrna sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "metabolomic analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49019', 'http://www.ebi.ac.uk/efo/EFO_0000752', 'http://purl.obolibrary.org/obo/NCIT_C25391', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110'}
# Ambiguous: "bv-2 cells" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/BTO_0003350', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous: "fecal microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841', 'http://purl.obolibrary.org/obo/OHMI_0000002'}
# Ambiguous: "people" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C18241', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "digestive tract" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://snomed.info/id/1255345008'}
# Ambiguous: "mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C45247', 'http://purl.obolibrary.org/obo/NCIT_C14424'}
# Ambiguous: "eae mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C94604', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "microbiome alterations" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C28344'}
# Ambiguous: "stenotrophomonas" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1236', 'http://purl.obolibrary.org/obo/NCBITaxon_40323'}
# Ambiguous: "late-onset alzheimer's disease" (label: DDF) has multiple URIs: {'http://www.ebi.ac.uk/efo/EFO_1001870', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "psd-95" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C29570', 'http://purl.obolibrary.org/obo/CHEBI_198287'}
# Ambiguous: "tnf-α" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/PR_P06804', 'http://purl.obolibrary.org/obo/NCIT_C20535'}
# Ambiguous: "il-10" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20512', 'http://purl.obolibrary.org/obo/NCIT_C28600'}
# Ambiguous: "female mice" (label: animal) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "ketogenic diet" (label: food) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000072001', 'http://snomed.info/id/765060000'}
# Ambiguous: "lactobacillus reuteri" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C76352', 'http://purl.obolibrary.org/obo/NCBITaxon_1598'}
# Ambiguous: "humans" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_9605', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "csf" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C387', 'http://purl.obolibrary.org/obo/NCIT_C12692'}
# Ambiguous: "fa" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_213421', 'http://purl.obolibrary.org/obo/NCIT_C184730'}
# Ambiguous: "16 s rdna sequencing" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/68017421', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "female rats" (label: animal) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C160998'}
# Ambiguous: "females" (label: animal) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000004', 'http://purl.obolibrary.org/obo/NCIT_C46110'}
# Ambiguous: "males" (label: animal) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000005', 'http://purl.obolibrary.org/obo/NCIT_C14366'}
# Ambiguous: "gut microbiome dysbiosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous: "t2d subjects" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "actinobacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2013654', 'http://id.nlm.nih.gov/mesh/D039903'}
# Ambiguous: "fecal microbiota transplantation" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000001', 'http://purl.obolibrary.org/obo/NCIT_C118643'}
# Ambiguous: "fmt" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000001', 'http://purl.obolibrary.org/obo/NCIT_C118643'}
# Ambiguous: "cognitive function" (label: DDF) has multiple URIs: {'http://snomed.info/id/373930000', 'http://purl.obolibrary.org/obo/NCIT_C16446'}
# Ambiguous: "16s ribosomal rna sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "y-maze" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000073219', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000014'}
# Ambiguous: "pro-inflammatory cytokines" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20464', 'http://purl.obolibrary.org/obo/NCIT_C50928'}
# Ambiguous: "erysipelatoclostridium" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_3025755', 'http://id.nlm.nih.gov/mesh/D004888'}
# Ambiguous: "gut barrier disruption" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C25486'}
# Ambiguous: "metastatic colorectal cancer" (label: DDF) has multiple URIs: {'http://www.ebi.ac.uk/efo/EFO_1001480', 'http://purl.obolibrary.org/obo/NCIT_C2955'}
# Ambiguous: "persons" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "neurodegenerative disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://id.nlm.nih.gov/mesh/D019636'}
# Ambiguous: "tau protein" (label: chemical) has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/NCIT_C75652', 'http://purl.obolibrary.org/obo/NCIT_C26532'}
# Ambiguous: "nrf2" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/NCIT_C54255'}
# Ambiguous: "autophagy" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C71427', 'http://id.nlm.nih.gov/mesh/D000080549'}
# Ambiguous: "p62" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C491079', 'http://purl.obolibrary.org/obo/OMIT_0037033'}
# Ambiguous: "synaptic loss" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C195952', 'https://uts.nlm.nih.gov/uts/umls/concept/C5394342'}
# Ambiguous: "gut microbiota disorder" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous: "anxiety-like behavior" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://www.ebi.ac.uk/efo/EFO_1001877'}
# Ambiguous: "shuttle box" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/MMO_0000725', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous: "ad group" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "anxiety-related behavior" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://www.ebi.ac.uk/efo/EFO_1001877'}
# Ambiguous: "gut microbiota-derived metabolite" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000150', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "adults" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000328', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "probiotic group" (label: human) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "synbiotic group" (label: human) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "placebo group" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "prebiotic diet" (label: food) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000072001', 'http://purl.obolibrary.org/obo/NCIT_C15222'}
# Ambiguous: "brain disorders" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C96413', 'http://purl.obolibrary.org/obo/NCIT_C2991'}
# Ambiguous: "spf mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_9989', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "pd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous: "healthy spouses" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C62649', 'http://purl.obolibrary.org/obo/OMIT_0018651'}
# Ambiguous: "extracellular vesicles" (label: chemical) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000049', 'http://purl.obolibrary.org/obo/OMIT_0001136'}
# Ambiguous: "bactev" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C153165', 'http://purl.obolibrary.org/obo/OMIT_0001136'}
# Ambiguous: "tissues" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C38625', 'http://purl.obolibrary.org/obo/NCIT_C12801'}
# Ambiguous: "16s rrna gene sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "behavioural deficits" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C116921', 'http://snomed.info/id/284501001'}
# Ambiguous: "gut microbiome composition" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "gut microbiota alterations" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C28344'}
# Ambiguous: "pd" (label: human) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000092', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous: "neurodegenerative disorder" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39737', 'http://purl.obolibrary.org/obo/NCIT_C195952'}
# Ambiguous: "intraperitoneal injection" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25409', 'http://purl.obolibrary.org/obo/NCIT_C28160'}
# Ambiguous: "antibiotics treatment" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49236', 'http://purl.obolibrary.org/obo/NCIT_C15620'}
# Ambiguous: "pd mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "propionate" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61911', 'http://purl.obolibrary.org/obo/NCIT_C2337', 'http://purl.obolibrary.org/obo/OMIT_0012372'}
# Ambiguous: "ginsenoside rk3" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C472075', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous: "depressive-like behavior" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26696', 'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous: "nervous system" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12755', 'http://purl.obolibrary.org/obo/NCIT_C12438'}
# Ambiguous: "rk3" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/C472075', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous: "depression-like behavior" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/OMIT_0005141', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous: "brain tissue" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://snomed.info/id/256865009'}
# Ambiguous: "butyricimonas" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://id.nlm.nih.gov/mesh/D045856', 'http://purl.obolibrary.org/obo/NCBITaxon_976'}
# Ambiguous: "subjects" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C18241', 'http://id.nlm.nih.gov/mesh/D010361', 'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C70668', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "autism spectrum disorder" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C97161', 'http://purl.obolibrary.org/obo/NCIT_C89330', 'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C26835'}
# Ambiguous: "children" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D002648', 'http://purl.obolibrary.org/obo/NCIT_C42708'}
# Ambiguous: "asd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C88412', 'http://purl.obolibrary.org/obo/NCIT_C97161'}
# Ambiguous: "parkinson's and alzheimer's diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "tgr5" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26103', 'http://purl.obolibrary.org/obo/NCIT_C2304'}
# Ambiguous: "ischemic stroke" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95802', 'http://purl.obolibrary.org/obo/NCIT_C3390'}
# Ambiguous: "social isolation" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C21100', 'https://uts.nlm.nih.gov/uts/umls/concept/C0855237'}
# Ambiguous: "intestinal barrier" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49240', 'http://purl.obolibrary.org/obo/NCIT_C34082', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000191', 'http://purl.obolibrary.org/obo/NCIT_C93019', 'http://snomed.info/id/360972004', 'http://purl.obolibrary.org/obo/NCIT_C49478'}
# Ambiguous: "male balb/c mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C37357', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "bifidobacterium longum" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1678', 'http://purl.obolibrary.org/obo/NCIT_C86199'}
# Ambiguous: "chronic unpredictable mild stress" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1510527', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous: "cums" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C1510527', 'http://purl.obolibrary.org/obo/NCIT_C35041'}
# Ambiguous: "lc3" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C104677', 'http://purl.obolibrary.org/obo/CHEBI_36080'}
# Ambiguous: "mptp" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_233275', 'http://purl.obolibrary.org/obo/CHEBI_17963'}
# Ambiguous: "bile salt hydrolase" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16701', 'http://purl.obolibrary.org/obo/CHEBI_22868'}
# Ambiguous: "bsh" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16701', 'http://purl.obolibrary.org/obo/CHEBI_22868'}
# Ambiguous: "glp-1r" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_80270', 'http://purl.obolibrary.org/obo/OMIT_0001212', 'http://purl.obolibrary.org/obo/NCIT_C18106'}
# Ambiguous: "sod" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D013482', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous: "nf-κb" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCIT_C17380'}
# Ambiguous: "hcs" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C28143', 'http://purl.obolibrary.org/obo/NCIT_C94342', 'http://purl.obolibrary.org/obo/NCBITaxon_9605'}
# Ambiguous: "alpha diversity indices" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000471', 'http://purl.obolibrary.org/obo/PCO_0000062'}
# Ambiguous: "peripheral tissues" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25233', 'http://purl.obolibrary.org/obo/NCIT_C38625'}
# Ambiguous: "alzheimer's and parkinson's disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C26845'}
# Ambiguous: "major depression" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/NCIT_C35094'}
# Ambiguous: "frontal cortex" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C177766', 'http://purl.obolibrary.org/obo/NCIT_C154779'}
# Ambiguous: "cerebellum" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12439', 'http://purl.obolibrary.org/obo/NCIT_C12445'}
# Ambiguous: "heart" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13023', 'http://purl.obolibrary.org/obo/NCIT_C12727'}
# Ambiguous: "neurological disorders" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'http://id.nlm.nih.gov/mesh/D009461', 'http://purl.obolibrary.org/obo/NCIT_C26835'}
# Ambiguous: "16s rrna gene amplicon sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "serum metabolome" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13325', 'http://purl.obolibrary.org/obo/CHEBI_85234', 'http://purl.obolibrary.org/obo/NCIT_C210457'}
# Ambiguous: "bacteroides vulgatus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C86182', 'http://id.nlm.nih.gov/mesh/D001439'}
# Ambiguous: "serum metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_85234', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "glutamate" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C1115', 'http://purl.obolibrary.org/obo/NCIT_C687'}
# Ambiguous: "butyricicoccus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_580596', 'http://id.nlm.nih.gov/mesh/D045856', 'http://purl.obolibrary.org/obo/NCBITaxon_186801'}
# Ambiguous: "gut mycobiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/OHMI_0000006'}
# Ambiguous: "gut bacterial dysbiosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://snomed.info/id/1149492007'}
# Ambiguous: "mycobiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://purl.obolibrary.org/obo/NCBITaxon_749906', 'http://purl.obolibrary.org/obo/OHMI_0000006'}
# Ambiguous: "intestinal microbiome" (label: microbiome) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "relapsing-remitting multiple sclerosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C165675', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "ms disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3243', 'http://purl.obolibrary.org/obo/NCIT_C34527'}
# Ambiguous: "is" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95802', 'http://purl.obolibrary.org/obo/NCIT_C3390'}
# Ambiguous: "neuronal cells" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C12623', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous: "interleukin-6" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_52998', 'http://purl.obolibrary.org/obo/NCIT_C50940', 'http://purl.obolibrary.org/obo/OMIT_0016485'}
# Ambiguous: "western blot" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_37704', 'http://id.nlm.nih.gov/mesh/D015153'}
# Ambiguous: "proteins" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/CHEBI_82131'}
# Ambiguous: "tnf" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C20500', 'http://purl.obolibrary.org/obo/NCIT_C20535'}
# Ambiguous: "neurological deficits" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C37940', 'http://id.nlm.nih.gov/mesh/D009461'}
# Ambiguous: "untargeted metabolomics" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49019', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000110'}
# Ambiguous: "danggui shaoyao san" (label: drug) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C459', 'http://purl.obolibrary.org/obo/NCIT_C113297'}
# Ambiguous: "dss" (label: drug) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C459', 'http://id.nlm.nih.gov/mesh/C531150', 'http://purl.obolibrary.org/obo/NCIT_C113297'}
# Ambiguous: "hematoxylin and eosin (he) staining" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C23011', 'http://purl.obolibrary.org/obo/NCIT_C23010'}
# Ambiguous: "16s rdna sequencing" (label: biomedical technique) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5848503', 'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "rt-qpcr" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C51962', 'http://purl.obolibrary.org/obo/NCIT_C17003'}
# Ambiguous: "gsh-px" (label: chemical) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D005979', 'http://purl.obolibrary.org/obo/NCIT_C16554'}
# Ambiguous: "oa" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/CHEBI_44658'}
# Ambiguous: "ad-like pathologies" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2866', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C26845', 'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/OMIT_0003283'}
# Ambiguous: "beneficial bacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089'}
# Ambiguous: "nlrp3 inflammasome-mediated neuroinflammation" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000090862', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous: "md" (label: food) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C3243', 'http://id.nlm.nih.gov/mesh/D038441'}
# Ambiguous: "age-related diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'https://uts.nlm.nih.gov/uts/umls/concept/C0851830'}
# Ambiguous: "clostridium butyricum" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D003013', 'http://purl.obolibrary.org/obo/NCIT_C86273'}
# Ambiguous: "tlr4" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_77161', 'http://purl.obolibrary.org/obo/NCIT_C24865'}
# Ambiguous: "inos" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16554', 'http://purl.obolibrary.org/obo/NCIT_C38565'}
# Ambiguous: "zo-1" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028142', 'http://purl.obolibrary.org/obo/OMIT_0028159', 'http://purl.obolibrary.org/obo/NCIT_C114824', 'http://purl.obolibrary.org/obo/CHEBI_3254', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous: "16s rrna gene sequencing analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "men" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14366', 'http://id.nlm.nih.gov/mesh/D008571'}
# Ambiguous: "women" (label: human) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D014930', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "subjective cognitive decline" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0850292', 'http://id.nlm.nih.gov/mesh/D060825'}
# Ambiguous: "neurological diseases" (label: DDF) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D019636', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656', 'http://purl.obolibrary.org/obo/NCIT_C26835'}
# Ambiguous: "neuropsychological assessments" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C165543', 'http://purl.obolibrary.org/obo/NCIT_C19646'}
# Ambiguous: "nc group" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49651', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "gut microbial metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "agathobacter" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2048137', 'http://purl.obolibrary.org/obo/NCBITaxon_1766253'}
# Ambiguous: "parabacteroides" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_375288', 'http://id.nlm.nih.gov/mesh/D001439', 'http://id.nlm.nih.gov/mesh/2042320'}
# Ambiguous: "hyperphosphorylated tau" (label: chemical) has multiple URIs: {'http://snomed.info/id/707776005', 'http://purl.obolibrary.org/obo/MP_0021015', 'http://purl.obolibrary.org/obo/NCIT_C75652'}
# Ambiguous: "myelin oligodendrocyte glycoprotein" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16642', 'http://purl.obolibrary.org/obo/NCIT_C200639'}
# Ambiguous: "immunohistochemical staining" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000192', 'http://purl.obolibrary.org/obo/NCIT_C23020'}
# Ambiguous: "qrt-pcr" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17003', 'http://id.nlm.nih.gov/mesh/D000082563'}
# ...
# Ambiguous: "aß" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_60425', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous: "ahr" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17273', 'http://purl.obolibrary.org/obo/NCIT_C18106'}
# Ambiguous: "cluster of differentiation 11b" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_59132', 'http://purl.obolibrary.org/obo/NCIT_C17373'}
# Ambiguous: "microbiota composition" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "altered gut microbiota composition" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/NCIT_C93019'}
# Ambiguous: "organic acids" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64709', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous: "flies" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_381473', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000085'}
# Ambiguous: "lactiplantibacillus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_33958', 'http://purl.obolibrary.org/obo/NCBITaxon_1590'}
# Ambiguous: "nitrogen" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61863', 'http://purl.obolibrary.org/obo/NCIT_C48807'}
# Ambiguous: "age-related pathologies" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'https://uts.nlm.nih.gov/uts/umls/concept/C0851830'}
# Ambiguous: "fatty liver disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C84444', 'http://purl.obolibrary.org/obo/MONDO_0004790'}
# Ambiguous: "pbc" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C196862', 'http://purl.obolibrary.org/obo/NCIT_C27167'}
# Ambiguous: "fecal metagenomics" (label: biomedical technique) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C5906995', 'http://purl.obolibrary.org/obo/NCBITaxon_1861841'}
# Ambiguous: "16 s rrna sequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192768', 'http://purl.obolibrary.org/obo/OBI_0002763'}
# Ambiguous: "control participants" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C29867', 'http://purl.obolibrary.org/obo/NCIT_C28143'}
# Ambiguous: "ruthenibacterium lactatiformans" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1550024', 'http://purl.obolibrary.org/obo/NCBITaxon_186801'}
# Ambiguous: "neutrophils" (label: anatomical location) has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/OMIT_0010527'}
# Ambiguous: "nk46" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_1678', 'http://purl.obolibrary.org/obo/NCIT_C86199'}
# Ambiguous: "c. butyricum" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D003013', 'http://purl.obolibrary.org/obo/NCIT_C86273'}
# Ambiguous: "histidine" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_25212', 'http://purl.obolibrary.org/obo/NCIT_C29597'}
# Ambiguous: "stool" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C189125', 'http://purl.obolibrary.org/obo/NCIT_C13234'}
# Ambiguous: "ad-like pathology" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C18189', 'http://purl.obolibrary.org/obo/NCIT_C195952', 'http://purl.obolibrary.org/obo/NCIT_C2866'}
# Ambiguous: "amyloid plaques" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C95603', 'http://purl.obolibrary.org/obo/NCIT_C54018', 'http://purl.obolibrary.org/obo/GO_0034205'}
# Ambiguous: "behavioral testing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_457483', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous: "bfubb" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCBITaxon_33078'}
# Ambiguous: "senescence-accelerated mouse prone 8 (samp8) mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "h&e staining" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C23011', 'http://purl.obolibrary.org/obo/NCIT_C23010'}
# Ambiguous: "aged samp8 mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "nucleic acids" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C48807', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous: "periodontal disease" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2991', 'http://purl.obolibrary.org/obo/NCIT_C63743'}
# Ambiguous: "blood microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000124'}
# Ambiguous: "gut microbiome analysis" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000187'}
# Ambiguous: "candidatus arthromitus" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCBITaxon_33078'}
# Ambiguous: "galt" (label: anatomical location) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000198', 'http://purl.obolibrary.org/obo/NCIT_C13049'}
# Ambiguous: "aβ<sub>42</sub>" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_64647', 'http://purl.obolibrary.org/obo/CHEBI_64645'}
# Ambiguous: "enteric microbiome" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OHMI_0000020', 'http://id.nlm.nih.gov/mesh/D000069196'}
# Ambiguous: "leptotrichia" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_2', 'http://purl.obolibrary.org/obo/NCIT_C86014'}
# Ambiguous: "fecal bacteria" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://id.nlm.nih.gov/mesh/D000069196', 'http://purl.obolibrary.org/obo/NCBITaxon_2'}
# Ambiguous: "gut microbiome community" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000200'}
# Ambiguous: "ms twins" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://id.nlm.nih.gov/mesh/D010361'}
# Ambiguous: "cells" (label: anatomical location) has multiple URIs: {'http://snomed.info/id/250436000', 'http://purl.obolibrary.org/obo/NCIT_C12508'}
# Ambiguous: "americans" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C16310', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "transepithelial electrical resistance" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017097', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000062'}
# Ambiguous: "teer" (label: biomedical technique) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D017097', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000062'}
# Ambiguous: "adonis test" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C53241', 'http://id.nlm.nih.gov/mesh/D015999'}
# Ambiguous: "alcohol" (label: food) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D000088082', 'http://purl.obolibrary.org/obo/NCIT_C2190', 'http://purl.obolibrary.org/obo/NCIT_C86036'}
# Ambiguous: "da" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_18243', 'http://purl.obolibrary.org/obo/CHEBI_42111'}
# Ambiguous: "dopaminergic neuronal damage" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/HP_0002529'}
# Ambiguous: "chronic inflammatory diseases" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C93210', 'http://purl.obolibrary.org/obo/NCIT_C174450', 'http://purl.obolibrary.org/obo/NCIT_C3137'}
# Ambiguous: "anti-gal" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C121503', 'http://purl.obolibrary.org/obo/NCIT_C16295'}
# Ambiguous: "ace" (label: statistical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C19247', 'http://purl.obolibrary.org/obo/NCIT_C19044'}
# Ambiguous: "experimental autoimmune encephalitis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C26760', 'http://purl.obolibrary.org/obo/NCIT_C3006'}
# Ambiguous: "nmd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028544', 'http://purl.obolibrary.org/obo/CHEBI_31882'}
# Ambiguous: "buried food test" (label: biomedical technique) has multiple URIs: {'http://snomed.info/id/252249003', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous: "pole descent test" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C47891', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000186'}
# Ambiguous: "pyriform cortex" (label: anatomical location) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D066195', 'http://purl.obolibrary.org/obo/NCIT_C12443'}
# Ambiguous: "pms" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'https://uts.nlm.nih.gov/uts/umls/concept/C4699656', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "indole-3-lactic acid" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_42111', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous: "metabolite-sensing gpcrs" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C39001', 'http://purl.obolibrary.org/obo/NCIT_C18239'}
# Ambiguous: "p-cresol" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_76969', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous: "intestinal cells" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C49240', 'http://snomed.info/id/250436000'}
# Ambiguous: "campylobacterota" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_29547', 'http://id.nlm.nih.gov/mesh/D020560'}
# Ambiguous: "retinoic acid" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C68301', 'http://purl.obolibrary.org/obo/CHEBI_37527'}
# Ambiguous: "pyrosequencing" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C99481', 'http://purl.obolibrary.org/obo/NCIT_C101293'}
# Ambiguous: "genetically predisposed individuals" (label: human) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C25190', 'http://purl.obolibrary.org/obo/NCIT_C14225'}
# Ambiguous: "fecal and oral microbiomes" (label: microbiome) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0028418', 'http://purl.obolibrary.org/obo/OHMI_0000015'}
# Ambiguous: "muc2" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0010119', 'http://purl.obolibrary.org/obo/NCIT_C115187'}
# Ambiguous: "total cholesterol" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C61032', 'http://purl.obolibrary.org/obo/CHEBI_16113'}
# Ambiguous: "psmd" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/OMIT_0024149', 'http://purl.obolibrary.org/obo/NCIT_C16342'}
# Ambiguous: "depression-like behaviours" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C124639', 'http://purl.obolibrary.org/obo/MP_0003360'}
# Ambiguous: "tryptophan metabolism" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_27897', 'http://purl.obolibrary.org/obo/NCIT_C129885'}
# Ambiguous: "y maze test" (label: biomedical technique) has multiple URIs: {'http://purl.obolibrary.org/obo/MMO_0000609', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000014'}
# Ambiguous: "neuronal senescence" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C17467', 'http://id.nlm.nih.gov/mesh/D016922'}
# Ambiguous: "central nervous system autoimmunity" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2934', 'http://purl.obolibrary.org/obo/OMIT_0016272'}
# Ambiguous: "small intestine lymphoid tissues" (label: anatomical location) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C13049', 'http://purl.obolibrary.org/obo/NCIT_C12386'}
# Ambiguous: "zinc chloride" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C29865', 'http://purl.obolibrary.org/obo/NCIT_C948'}
# Ambiguous: "enterobacteriales" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCBITaxon_91347', 'http://purl.obolibrary.org/obo/NCIT_C76310'}
# Ambiguous: "3 × tg-ad mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://id.nlm.nih.gov/mesh/D055647'}
# Ambiguous: "hd mice" (label: animal) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14240', 'http://purl.obolibrary.org/obo/NCIT_C45247'}
# Ambiguous: "microbiota metabolites" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_82933', 'http://purl.obolibrary.org/obo/CHEBI_25212'}
# Ambiguous: "hplc" (label: biomedical technique) has multiple URIs: {'http://w3id.org/hereditary/ontology/gutbrain/resource/H000048', 'http://purl.obolibrary.org/obo/NCIT_C16434'}
# Ambiguous: "kyna" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_28683', 'http://purl.obolibrary.org/obo/CHEBI_18344'}
# Ambiguous: "microglia activation" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C64382', 'http://purl.obolibrary.org/obo/GO_0001774'}
# Ambiguous: "cns-directed autoimmunity" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C2934', 'http://purl.obolibrary.org/obo/OMIT_0016272'}
# Ambiguous: "p21" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/CHEBI_36080', 'http://purl.obolibrary.org/obo/NCIT_C17783'}
# Ambiguous: "svd" (label: DDF) has multiple URIs: {'https://uts.nlm.nih.gov/uts/umls/concept/C0262405', 'http://id.nlm.nih.gov/mesh/D059345'}
# Ambiguous: "human gut commensal" (label: bacteria) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C14329', 'http://w3id.org/hereditary/ontology/gutbrain/resource/H000089'}
# Ambiguous: "weighted gene co-expression network analysis" (label: statistical technique) has multiple URIs: {'http://edamontology.org/operation_3766', 'http://purl.obolibrary.org/obo/NCIT_C25391'}
# Ambiguous: "rps3a" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/OMIT_0034986'}
# Ambiguous: "rpl5" (label: gene) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C16612', 'http://purl.obolibrary.org/obo/NCIT_C107652'}
# Ambiguous: "pediatric multiple sclerosis" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/MONDO_0018784', 'http://purl.obolibrary.org/obo/NCIT_C3243'}
# Ambiguous: "viral-induced neurologic damage" (label: DDF) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C50670', 'http://purl.obolibrary.org/obo/NCIT_C61555'}
# Ambiguous: "thc" (label: drug) has multiple URIs: {'http://snomed.info/id/72024007', 'http://purl.obolibrary.org/obo/NCIT_C459'}
# Ambiguous: "pip" (label: chemical) has multiple URIs: {'http://purl.obolibrary.org/obo/NCIT_C192634', 'http://purl.obolibrary.org/obo/CHEBI_22315'}
# Ambiguous: "e. faecalis" (label: bacteria) has multiple URIs: {'http://id.nlm.nih.gov/mesh/D016983', 'http://purl.obolibrary.org/obo/NCIT_C86368'}
#
# === Text Span + Label Analysis ===
# Total unique (text_span, label) pairs: 14804
# Pairs with multiple URIs: 911

# %% [markdown]
# ## Step 2: Analyze Exact Match Coverage on Predictions
#
# Evaluate how many predicted entities can be linked using exact matches from our training data mappings. We test both text-only and text+label matching strategies.

# %% [markdown]
# ### Coverage Analysis: Text + Label Matching
#
# Test exact match coverage using the more precise (text_span, label) mapping approach.

# %%
# Load predicted entities for coverage analysis
predictions_file_path = '../../Predictions/NER/predicted_entities_test_0.65_eval_format.json'
with open(predictions_file_path, 'r', encoding='utf-8') as input_file:
    predicted_entities_data = json.load(input_file)

# Analyze coverage using (text_span, label) matching
exact_matches_with_label = 0
missed_entities_with_label = 0
missed_entities_for_similarity = {}
missed_entity_index = 0

print("Analyzing exact match coverage with (text_span, label) approach...")

for document_id, document_content in predicted_entities_data.items():
    for predicted_entity in document_content['entities']:
        normalized_text_span = predicted_entity['text_span'].lower()
        entity_label = predicted_entity['label']
        composite_key = (normalized_text_span, entity_label)

        if composite_key in text_span_label_to_uris:
            exact_matches_with_label += 1
        else:
            missed_entities_with_label += 1
            # Store missed entity for similarity matching
            missed_entities_for_similarity[missed_entity_index] = (
                predicted_entity['text_span'],
                entity_label
            )
            missed_entity_index += 1

print(f'\n=== Coverage Analysis (Text + Label) ===')
print(f'Exact matches: {exact_matches_with_label}')
print(f'Missed entities: {missed_entities_with_label}')
print(f'Coverage rate: {(exact_matches_with_label / (exact_matches_with_label + missed_entities_with_label) * 100):.1f}%')

# Save missed entities for similarity matching
MISSED_ENTITIES_FILE = 'missed_ents_text_and_label.json'
with open(MISSED_ENTITIES_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(missed_entities_for_similarity, output_file, indent=4)

print(f'\nSaved {len(missed_entities_for_similarity)} missed entities to {MISSED_ENTITIES_FILE}')
# Out:
# Analyzing exact match coverage with (text_span, label) approach...
#
# === Coverage Analysis (Text + Label) ===
# Exact matches: 1226
# Missed entities: 1581
# Coverage rate: 43.7%
#
# Saved 1581 missed entities to missed_ents_text_and_label.json

# %% [markdown]
# ### Coverage Analysis: Text-Only Matching + Missed Entity Collection
#
# Test coverage using text-only matching (more permissive) and collect entities that cannot be matched for similarity-based linking.

# %%
# Analyze coverage using text-only matching and collect missed entities
exact_matches_text_only = 0
missed_entities_text_only = 0
missed_entities_for_similarity = {}
missed_entity_index = 0

print("Analyzing exact match coverage with text-only approach...")

for document_id, document_content in predicted_entities_data.items():
    for predicted_entity in document_content['entities']:
        normalized_text_span = predicted_entity['text_span'].lower()
        entity_label = predicted_entity['label']

        if normalized_text_span in text_span_to_uris:
            exact_matches_text_only += 1
        else:
            missed_entities_text_only += 1
            # Store missed entity for similarity matching
            missed_entities_for_similarity[missed_entity_index] = (
                predicted_entity['text_span'],
                entity_label
            )
            missed_entity_index += 1

print(f'\n=== Coverage Analysis (Text Only) ===')
print(f'Exact matches: {exact_matches_text_only}')
print(f'Missed entities: {missed_entities_text_only}')
print(f'Coverage rate: {(exact_matches_text_only / (exact_matches_text_only + missed_entities_text_only) * 100):.1f}%')

# Save missed entities for similarity matching
MISSED_ENTITIES_FILE = 'missed_ents_text_only.json'
with open(MISSED_ENTITIES_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(missed_entities_for_similarity, output_file, indent=4)

print(f'\nSaved {len(missed_entities_for_similarity)} missed entities to {MISSED_ENTITIES_FILE}')
# Out:
# Analyzing exact match coverage with text-only approach...
#
# === Coverage Analysis (Text Only) ===
# Exact matches: 1864
# Missed entities: 943
# Coverage rate: 66.4%
#
# Saved 943 missed entities to missed_ents_text_only.json

# %% [markdown]
# ## Step 3: Semantic Similarity Matching
#
# For entities that couldn't be matched exactly, use semantic similarity with PubMedBERT embeddings to find the most similar URI definitions from our knowledge base.
#
# **Process**:
# 1. Load pre-generated URI definitions
# 2. Build embedding index using txtai + PubMedBERT
# 3. Query missed entities against the definition corpus
# 4. Return top-10 most similar definitions for each missed entity

# %% [markdown]
# ### Build Embedding Index and Perform Similarity Search
#
# **GPU Recommended**: This step uses PubMedBERT embeddings which benefit significantly from GPU acceleration.

# %%
# !pip install txtai libChEBIpy requests beautifulsoup4
# Out:
# Collecting txtai
#   Downloading txtai-9.8.0-py3-none-any.whl.metadata (33 kB)
# Collecting libChEBIpy
#   Downloading libChEBIpy-1.0.10-py3-none-any.whl.metadata (677 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Collecting faiss-cpu>=1.7.1.post2 (from txtai)
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: msgpack>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from txtai) (1.1.2)
# Requirement already satisfied: torch>=2.4 in /usr/local/lib/python3.12/dist-packages (from txtai) (2.10.0+cu128)
# Requirement already satisfied: transformers>=4.56.2 in /usr/local/lib/python3.12/dist-packages (from txtai) (5.0.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from txtai) (1.11.0)
# Requirement already satisfied: numpy>=1.18.4 in /usr/local/lib/python3.12/dist-packages (from txtai) (2.0.2)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from txtai) (6.0.3)
# Requirement already satisfied: regex>=2022.8.17 in /usr/local/lib/python3.12/dist-packages (from txtai) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.5 in /usr/local/lib/python3.12/dist-packages (from txtai) (0.7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from libChEBIpy) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.4.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu>=1.7.1.post2->txtai) (26.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->txtai) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->txtai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->txtai) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->txtai) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->txtai) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->txtai) (0.24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->txtai) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.4->txtai) (1.5.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->txtai) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->txtai) (0.24.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.34.0->txtai) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.34.0->txtai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.34.0->txtai) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4->txtai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4->txtai) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.34.0->txtai) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.34.0->txtai) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.34.0->txtai) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.34.0->txtai) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.34.0->txtai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.34.0->txtai) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.34.0->txtai) (0.1.2)
# Downloading txtai-9.8.0-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.4/312.4 kB 9.9 MB/s eta 0:00:00
# Downloading libChEBIpy-1.0.10-py3-none-any.whl (18 kB)
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 118.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu, libChEBIpy, txtai
# Successfully installed faiss-cpu-1.13.2 libChEBIpy-1.0.10 txtai-9.8.0

# %%
import txtai
from tqdm import tqdm
import os

print("Initializing PubMedBERT embeddings model...")
# Initialize txtai embeddings with PubMedBERT (biomedical domain-specific)
embeddings_model = txtai.Embeddings(path="neuml/pubmedbert-base-embeddings", content=True)

# Load URI definitions for embedding indexing
URI_DEFINITIONS_FILE = 'definitions/split_uri_definitions.json'
with open(URI_DEFINITIONS_FILE, 'r', encoding='utf-8') as input_file:
    uri_definitions_data = json.load(input_file)

print(f"Loaded {len(uri_definitions_data)} URI definitions")

if os.path.exists("embeddings_index"):
    print("Embeddings index already exists. Loading existing index...")
    embeddings_model.load("embeddings_index")
else:
    # Prepare data for indexing: (id, definition_text) tuples
    definitions_for_indexing = []
    for definition_id, definition_text in uri_definitions_data.items():
        definitions_for_indexing.append((definition_id, definition_text))

    print("Building embedding index... (this may take several minutes)")
    # Build the embedding index
    embeddings_model.index(definitions_for_indexing)

    # Save the index for future use
    print("Saving embedding index...")
    embeddings_model.save("embeddings_index") # Save in directory format
    embeddings_model.save("embeddings_index.tar.gz") # Also save as tar.gz for compatibility

# Load missed entities for similarity matching
MISSED_ENTITIES_FILE = 'missed_ents_text_only.json'
with open(MISSED_ENTITIES_FILE, 'r', encoding='utf-8') as input_file:
    missed_entities_data = json.load(input_file)

print(f"Performing similarity search for {len(missed_entities_data)} missed entities...")

# Perform similarity search for each missed entity
similarity_search_results = {}
for entity_id, (text_span, entity_label) in tqdm(missed_entities_data.items(), desc="Similarity matching"):
    # Search for top 10 most similar definitions
    search_results = embeddings_model.search(text_span, 10)

    similarity_search_results[entity_id] = {
        'text_span': text_span,
        'label': entity_label,
        'similarity_results': search_results
    }

# Save similarity results
SIMILARITY_RESULTS_FILE = 'similarity_matching_results.json'
with open(SIMILARITY_RESULTS_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(similarity_search_results, output_file, ensure_ascii=False, indent=4)

print(f"Similarity matching completed. Results saved to {SIMILARITY_RESULTS_FILE}")
# Out:
# Initializing PubMedBERT embeddings model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Loaded 28077 URI definitions
# Embeddings index already exists. Loading existing index...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Performing similarity search for 943 missed entities...
# Similarity matching: 100%|██████████| 943/943 [00:09<00:00, 99.43it/s]
# Similarity matching completed. Results saved to similarity_matching_results.json

# %% [markdown]
# ## Step 4: Analyze Similarity Matching Results
#
# Process and analyze the similarity matching results to understand the quality and distribution of matches.

# %% [markdown]
# ### Data Format Conversion and Statistical Analysis
#
# Convert similarity results to different formats and analyze the distribution of similarity scores.

# %%
import json
import pickle

def convert_json_to_pickle(json_file_path, pickle_file_path):
    """Convert JSON file to pickle format for faster loading."""
    with open(json_file_path, 'r', encoding='utf-8') as input_file:
        data = json.load(input_file)

    with open(pickle_file_path, 'wb') as output_file:
        pickle.dump(data, output_file)

    print(f"Converted {json_file_path} to {pickle_file_path}")

def load_pickle_data(pickle_file_path):
    """Load data from pickle file."""
    with open(pickle_file_path, 'rb') as input_file:
        data = pickle.load(input_file)
    return data

# Convert similarity results to pickle format
SIMILARITY_RESULTS_JSON = 'similarity_matching_results.json'
SIMILARITY_RESULTS_PICKLE = 'similarity_matching_results.pkl'

convert_json_to_pickle(SIMILARITY_RESULTS_JSON, SIMILARITY_RESULTS_PICKLE)
similarity_results_dict = load_pickle_data(SIMILARITY_RESULTS_PICKLE)
# Out:
# Converted similarity_matching_results.json to similarity_matching_results.pkl

# %%
from pprint import pprint

# Analyze similarity score distributions
total_similarity_score = 0
min_similarity_score = float('inf')
max_similarity_score = float('-inf')
total_entities_count = 0
all_top_scores = []

print("Analyzing similarity score distributions...")

# Collect top similarity scores for each entity
for entity_id, entity_data in similarity_results_dict.items():
    # Get the top similarity result (index 0)
    top_similarity_score = entity_data['similarity_results'][0]['score']

    # Update statistics
    total_similarity_score += top_similarity_score
    min_similarity_score = min(min_similarity_score, top_similarity_score)
    max_similarity_score = max(max_similarity_score, top_similarity_score)
    all_top_scores.append(top_similarity_score)
    total_entities_count += 1

# Sort scores for percentile analysis
all_top_scores.sort()

# Calculate average
average_similarity_score = total_similarity_score / total_entities_count if total_entities_count > 0 else 0

print(f"\n=== Similarity Score Analysis ===")
print(f"Total entities analyzed: {total_entities_count}")

# Show distribution of scores at different thresholds
print(f"\n=== Score Distribution Analysis ===")
for threshold_percent in range(10, 100, 10):
    threshold_value = threshold_percent / 100
    entities_below_threshold = sum(1 for score in all_top_scores if score < threshold_value)
    percentage_below = (entities_below_threshold / total_entities_count) * 100 if total_entities_count > 0 else 0

    print(f"Entities with similarity < {threshold_value:.2f}: {entities_below_threshold} ({percentage_below:.2f}%)")

print(f"\n=== Summary Statistics ===")
pprint({
    "average_similarity_score": round(average_similarity_score, 4),
    "min_similarity_score": round(min_similarity_score, 4),
    "max_similarity_score": round(max_similarity_score, 4),
    "median_score": round(all_top_scores[len(all_top_scores)//2], 4) if all_top_scores else 0
})
# Out:
# Analyzing similarity score distributions...
#
# === Similarity Score Analysis ===
# Total entities analyzed: 943
#
# === Score Distribution Analysis ===
# Entities with similarity < 0.10: 0 (0.00%)
# Entities with similarity < 0.20: 0 (0.00%)
# Entities with similarity < 0.30: 0 (0.00%)
# Entities with similarity < 0.40: 0 (0.00%)
# Entities with similarity < 0.50: 10 (1.06%)
# Entities with similarity < 0.60: 78 (8.27%)
# Entities with similarity < 0.70: 209 (22.16%)
# Entities with similarity < 0.80: 378 (40.08%)
# Entities with similarity < 0.90: 637 (67.55%)
#
# === Summary Statistics ===
# {'average_similarity_score': 0.8179,
#  'max_similarity_score': 1.0,
#  'median_score': 0.8361,
#  'min_similarity_score': 0.4467}

# %% [markdown]
# ### Process Similarity Results for Entity Linking
#
# Extract the top similarity match for each entity and prepare the mapping for final linking.

# %%
# Load similarity results
SIMILARITY_RESULTS_FILE = 'similarity_matching_results.json'
with open(SIMILARITY_RESULTS_FILE, 'r', encoding='utf-8') as input_file:
    similarity_results = json.load(input_file)

# Create mapping from text spans to top similarity match definition IDs
text_span_to_definition_id = {}

print("Processing similarity results to extract top matches...")

for entity_id, entity_data in similarity_results.items():
    entity_text_span = entity_data['text_span']
    top_similarity_result = entity_data['similarity_results'][0]  # Get top match
    top_definition_id = top_similarity_result['id']

    # Map text span to the ID of the most similar definition
    text_span_to_definition_id[entity_text_span] = top_definition_id

# Save processed similarity mappings
PROCESSED_SIMILARITY_FILE = "processed_similarity_res.json"
with open(PROCESSED_SIMILARITY_FILE, "w", encoding="utf-8") as output_file:
    json.dump(text_span_to_definition_id, output_file, indent=2)

print(f"Processed similarity mappings for {len(text_span_to_definition_id)} entities")
print(f"Saved to {PROCESSED_SIMILARITY_FILE}")
# Out:
# Processing similarity results to extract top matches...
# Processed similarity mappings for 734 entities
# Saved to processed_similarity_res.json

# %% [markdown]
# ## Step 5: Final Entity Linking
#
# Combine exact matching and similarity matching to assign URIs to all predicted entities. The linking priority is:
#
# 1. **Exact Match**: Direct text span match from training data
# 2. **Similarity Match**: Best semantic match from embedding search
# 3. **No Match**: Assign 'NA' if neither method finds a suitable URI
#
# Each entity will be tagged with its URI source for transparency.

# %% [markdown]
# ### Apply Linking Strategy to All Predicted Entities
#
# Execute the complete linking pipeline on all predicted entities and generate the final output with linking statistics.

# %%
# Initialize linking statistics counters
exact_match_text_label_count = 0
exact_match_text_only_count = 0
similarity_match_count = 0
no_match_count = 0

# Load processed similarity mappings
PROCESSED_SIMILARITY_FILE = 'processed_similarity_res.json'
with open(PROCESSED_SIMILARITY_FILE, 'r', encoding='utf-8') as input_file:
    text_span_to_similarity_definition_id = json.load(input_file)

# Load definition ID to URI mapping
DEFINITION_ID_TO_URI_FILE = "definitions/id_to_uri.json"
with open(DEFINITION_ID_TO_URI_FILE, "r", encoding="utf-8") as input_file:
    definition_id_to_uri = json.load(input_file)

print("Loading training data for exact matching...")

# Rebuild exact matching dictionaries (text span + label -> URI) and (text span -> URI) from training data
# Here we are commenting out the dev set to avoid data leakage when running inference on the dev set
# When evaluating on the test set, uncomment this line to include the dev annotations in the knowledge base
#dev_annotations_path = '../../Annotations/Dev/json_format/dev.json'
train_gold_annotations_path = '../../Annotations/Train/gold_quality/json_format/train_gold.json'
train_silver_annotations_path = '../../Annotations/Train/silver_quality/json_format/train_silver.json'
train_silver_2025_annotations_path = '../../Annotations/Train/silver_quality/json_format/train_silver_2025.json'

training_annotation_files = [
    # dev_annotations_path,
    train_gold_annotations_path,
    train_silver_annotations_path,
    train_silver_2025_annotations_path,
]

# Rebuild exact matching mappings for both strategies
exact_text_span_to_uris = {}
exact_text_span_label_to_uris = {}

for annotation_file_path in training_annotation_files:
    with open(annotation_file_path, 'r', encoding='utf-8') as input_file:
        annotation_data = json.load(input_file)

    for document_id, document_content in annotation_data.items():
        for entity in document_content['entities']:
            normalized_text_span = entity['text_span'].lower()
            entity_label = entity['label']
            entity_uri = entity['uri']

            # Build text-only mapping
            if normalized_text_span not in exact_text_span_to_uris:
                exact_text_span_to_uris[normalized_text_span] = set()
            exact_text_span_to_uris[normalized_text_span].add(entity_uri)

            # Build text+label mapping
            composite_key = (normalized_text_span, entity_label)
            if composite_key not in exact_text_span_label_to_uris:
                exact_text_span_label_to_uris[composite_key] = set()
            exact_text_span_label_to_uris[composite_key].add(entity_uri)

# Load predicted entities for final linking
predictions_file_path = '../../Predictions/NER/predicted_entities_test_0.65_eval_format.json'
with open(predictions_file_path, "r", encoding="utf-8") as input_file:
    final_predictions = json.load(input_file)

print("Applying entity linking pipeline to all predicted entities...")

# Apply entity linking pipeline to each predicted entity
for document_id, document_content in final_predictions.items():
    for predicted_entity in document_content['entities']:
        entity_text_span = predicted_entity['text_span']
        normalized_text_span = entity_text_span.lower()
        entity_label = predicted_entity['label']
        composite_key = (normalized_text_span, entity_label)

        # Strategy 1: Try exact matching with text span + label first
        if composite_key in exact_text_span_label_to_uris:
            exact_match_text_label_count += 1
            # Use first URI from the set (as there could be multiple)
            assigned_uri = list(exact_text_span_label_to_uris[composite_key])[0]
            predicted_entity['uri'] = assigned_uri
            predicted_entity['uri_source'] = 'exact_match_text_label'

        # Strategy 2: Try exact matching with text span only
        elif normalized_text_span in exact_text_span_to_uris:
            exact_match_text_only_count += 1
            # Use first URI from the set (as there could be multiple)
            assigned_uri = list(exact_text_span_to_uris[normalized_text_span])[0]
            predicted_entity['uri'] = assigned_uri
            predicted_entity['uri_source'] = 'exact_match_text_only'

        # Strategy 3: Try similarity matching
        elif entity_text_span in text_span_to_similarity_definition_id:
            similarity_match_count += 1
            definition_id = text_span_to_similarity_definition_id[entity_text_span]
            assigned_uri = definition_id_to_uri[definition_id]
            predicted_entity['uri'] = assigned_uri
            predicted_entity['uri_source'] = 'similarity_match'

        # Strategy 4: No match found
        else:
            no_match_count += 1
            predicted_entity['uri'] = 'NA'
            predicted_entity['uri_source'] = 'no_match'

# Display final linking statistics
total_entities = exact_match_text_label_count + exact_match_text_only_count + similarity_match_count + no_match_count
print(f'\n=== Final Entity Linking Results ===')
print(f'Total entities processed: {total_entities}')
print(f'Exact matches (text + label): {exact_match_text_label_count} ({(exact_match_text_label_count/total_entities*100):.1f}%)')
print(f'Exact matches (text only): {exact_match_text_only_count} ({(exact_match_text_only_count/total_entities*100):.1f}%)')
print(f'Similarity matches: {similarity_match_count} ({(similarity_match_count/total_entities*100):.1f}%)')
print(f'No matches (NA): {no_match_count} ({(no_match_count/total_entities*100):.1f}%)')
print(f'Overall linking rate: {((exact_match_text_label_count + exact_match_text_only_count + similarity_match_count)/total_entities*100):.1f}%')

# Save final linked predictions
FINAL_PREDICTIONS_FILE = '../../Predictions/NEL/predicted_entities_test.json'
with open(FINAL_PREDICTIONS_FILE, 'w', encoding='utf-8') as output_file:
    json.dump(final_predictions, output_file, indent=4)

print(f'\nFinal linked predictions saved to: {FINAL_PREDICTIONS_FILE}')
# Out:
# Loading training data for exact matching...
# Applying entity linking pipeline to all predicted entities...
#
# === Final Entity Linking Results ===
# Total entities processed: 2807
# Exact matches (text + label): 1270 (45.2%)
# Exact matches (text only): 664 (23.7%)
# Similarity matches: 873 (31.1%)
# No matches (NA): 0 (0.0%)
# Overall linking rate: 100.0%
#
# Final linked predictions saved to: ../../Predictions/NEL/predicted_entities_test.json
